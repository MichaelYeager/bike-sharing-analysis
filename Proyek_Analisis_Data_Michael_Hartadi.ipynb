# %% [markdown]
# # Proyek Analisis Data: [Bike Sharing Dataset]
# - **Nama:** [Michael Hartadi Ginting]
# - **Email:** [cdcc319d6y1761@student.devacademy.id]
# - **ID Dicoding:** [CDCC319D6Y1761]

# %% [markdown]
# ## Menentukan Pertanyaan Bisnis

# %% [markdown]
# **SMART Question** adalah sebuah framework untuk merumuskan pertanyaan secara terstruktur agar memeperoleh informasi yang mendalam.
#
# * **Spesific (Spesifik)**
#   * Pertanyaan harus jelas, fokus pada sebuah topik tertentu, dan tidak bermakna ganda. Hindari pertanyaan yang terlalu luas.
#     * Salah: Bagaimana cara meningkatkan penjualan?
#     * Benar: Faktor apa saja yang memengaruhi penurunan penjualan produk kategori elektronik di wilayah Jakarta selama kuartal terakhir?
# * **Measurable (Terukur)**
#   * Pertanyaan harus bisa dijawab dengan angka atau matrix yang konkret, harus tahu apa yang akan dihitung.
#     * Salah: Apakah pelanggan senang dengan layanan kita?
#     * Benar: Berapa skor rata-rata Customer Satisfaction untuk layanan purna jual bulan ini dibandingkan bulan lalu?
# * **Action-Oriented (Berorientasi Aksi)**
#   * Hasil dari pertanyaan harus bisa memberikan arahan untuk melakukan tindakan nyata. Jika pertanyaan terjawab, stakeholder harus tahu apa langkah selanjutnya.
#     * Salah: Mengapa orang suka berbelanja?
#     * Benar: Fitur apa pada aplikasi yang paling sering digunakan sebelum pengguna memutuskan untuk melakukan checkout?
# * **Relevant (Relevan)**
#   * Hasil dari pertanyaan harus sejalan dengan tujuan utama bisnis atau masalah yang sedang dihadapi.
#     * Salah: Menanyakan tentang stok gudang saat masalah utamanya adalah efektivitas kampanye media sosial.
#     * Benar: Apakah kampanye iklan di Instagram memberikan Return on Ad Spend (ROAS) yang lebih tinggi dibandingkan iklan di TikTok?
# * **Time-bound (Terikat Waktu)**
#   * Pertanyaan harus ada batasan waktu yang jelas agar analisis memiliki konteks yang tepat.
#     * Salah: Berapa banyak pengguna baru kita?
#     * Benar: Berapa tingkat pertumbuhan pengguna baru secara bulanan (Month-over-Month) sepanjang tahun 2025?

# %% [markdown]
# **Contoh pertanyaan bisnis yang memenuhi seluruh elemen SMART**
#
# ***"Faktor apa saja yang memengaruhi penurunan conversion rate pada pengguna aplikasi Android di wilayah Jabodetabek sebesar 5% selama periode Flash Sale Maret 2026?"***
#
# Keterangan:
#
# - **Specific**: Fokus pada "penurunan conversion rate" untuk "aplikasi Android" di "Jabodetabek". Bukan sekadar penjualan turun.
# - **Measurable**: Ada angka konkret yang ingin dianalisis, yaitu penurunan sebesar "5%".
# - **Action-Oriented**: Dengan mengetahui faktor penyebabnya misalnya bug pada versi Android tertentu atau kendala logistik di Jabodetabek, tim bisa langsung melakukan perbaikan teknis atau operasional.
# - **Relevant**: Penurunan konversi saat Flash Sale adalah masalah kritis bagi bisnis retail/e-commerce.
# - **Time-bound**: Dibatasi pada periode spesifik "Flash Sale Maret 2026".

# %% [markdown]
# - **Pertanyaan 1:** Bagaimana pengaruh cuaca (weathersit) terhadap jumlah total penyewaan sepeda (cnt) selama tahun 2012?
# - **Pertanyaan 2:** Pada jam berapa penyewaan sepeda mencapai puncaknya pada hari kerja (workingday) dibandingkan hari libur (holiday)?

# %% [markdown]
# ## Import Semua Packages/Library yang Digunakan

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %% [markdown]
# ## Data Wrangling

# %% [markdown]
# ### Gathering Data

# %% [markdown]
# #### Load df ...

# %%
day_df = pd.read_csv("day.csv")
hour_df = pd.read_csv("hour.csv")

# %% [markdown]
# **Insight:** (Opsional)
# - xxx
# - xxx

# %% [markdown]
# ### Assessing Data

# %% [markdown]
# #### Identifying ... problem

# %%
print("--- Info Day DF ---")
day_df.info()
print("\n--- Missing Values Day DF ---")
print(day_df.isna().sum())
print("\n--- Duplicate Data Day DF ---")
print(day_df.duplicated().sum())

print("\n" + "="*30 + "\n")

print("--- Info Hour DF ---")
hour_df.info()
print("\n--- Missing Values Hour DF ---")
print(hour_df.isna().sum())
print("\n--- Duplicate Data Hour DF ---")
print(hour_df.duplicated().sum())
# Out:
# --- Info Day DF ---
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 731 entries, 0 to 730
# Data columns (total 16 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   instant     731 non-null    int64
#  1   dteday      731 non-null    object
#  2   season      731 non-null    int64
#  3   yr          731 non-null    int64
#  4   mnth        731 non-null    int64
#  5   holiday     731 non-null    int64
#  6   weekday     731 non-null    int64
#  7   workingday  731 non-null    int64
#  8   weathersit  731 non-null    int64
#  9   temp        731 non-null    float64
#  10  atemp       731 non-null    float64
#  11  hum         731 non-null    float64
#  12  windspeed   731 non-null    float64
#  13  casual      731 non-null    int64
#  14  registered  731 non-null    int64
#  15  cnt         731 non-null    int64
# dtypes: float64(4), int64(11), object(1)
# memory usage: 91.5+ KB
#
# --- Missing Values Day DF ---
# instant       0
# ...

# %% [markdown]
# **Steps to Take:**
# - xxx
# - xxx

# %% [markdown]
# **Insight:** (Opsional)
# - xxx
# - xxx

# %% [markdown]
# ### Cleaning Data

# %% [markdown]
# #### Fixing ... problem

# %%
# Mengubah dteday menjadi datetime
day_df['dteday'] = pd.to_datetime(day_df['dteday'])
hour_df['dteday'] = pd.to_datetime(hour_df['dteday'])

# Mapping kategori untuk analisis EDA
weather_map = {1: 'Clear', 2: 'Misty/Cloudy', 3: 'Light Rain/Snow', 4: 'Heavy Rain'}
day_df['weathersit'] = day_df['weathersit'].map(weather_map)
hour_df['weathersit'] = hour_df['weathersit'].map(weather_map)

season_map = {1: 'Spring', 2: 'Summer', 3: 'Fall', 4: 'Winter'}
day_df['season'] = day_df['season'].map(season_map)

# %% [markdown]
# **Insight:** (Opsional)
# - xxx
# - xxx

# %% [markdown]
# ## Exploratory Data Analysis (EDA)

# %%
# EDA Univariate: Deskripsi statistik jumlah penyewaan (cnt)
print("Statistik Deskriptif Penyewaan Harian:")
print(day_df['cnt'].describe())

# EDA Kategorikal: Pengaruh Cuaca (weathersit) terhadap total penyewaan
print("\nTotal Penyewaan berdasarkan Kondisi Cuaca:")
print(day_df.groupby(by="weathersit").agg({
    "cnt": ["mean", "sum", "max", "min"]
}))

# EDA Multivariate: Pola jam kerja vs hari libur per jam (hour_df)
print("\nRata-rata Penyewaan per Jam (Hari Kerja vs Hari Libur):")
# Menampilkan 10 rata-rata tertinggi untuk melihat jam puncak secara angka
peak_hours = hour_df.groupby(by=["workingday", "hr"]).agg({
    "cnt": "mean"
}).sort_values(by="cnt", ascending=False)
print(peak_hours.head(10))
# Out:
# Statistik Deskriptif Penyewaan Harian:
# count     731.000000
# mean     4504.348837
# std      1937.211452
# min        22.000000
# 25%      3152.000000
# 50%      4548.000000
# 75%      5956.000000
# max      8714.000000
# Name: cnt, dtype: float64
#
# Total Penyewaan berdasarkan Kondisi Cuaca:
#                          cnt
#                         mean      sum   max  min
# weathersit
# Clear            4876.786177  2257952  8714  431
# Light Rain/Snow  1803.285714    37869  4639   22
# Misty/Cloudy     4035.862348   996858  8362  605
#
# Rata-rata Penyewaan per Jam (Hari Kerja vs Hari Libur):
#                       cnt
# workingday hr
# 1          17  525.290581
#            18  492.226908
#            8   477.006048
# 0          13  372.731602
#            12  366.259740
#            14  364.645022
#            15  358.813853
#            16  352.727273
# 1          19  348.401606
# 0          17  323.549784

# %% [markdown]
# **Insight:** (Opsional)
# - xxx
# - xxx

# %% [markdown]
# ## Visualization & Explanatory Analysis

# %% [markdown]
# ### Pertanyaan 1: Bagaimana pengaruh cuaca (weathersit) terhadap jumlah total penyewaan sepeda (cnt) selama tahun 2012?

# %%
plt.figure(figsize=(10, 6))
df_2012 = day_df[day_df['yr'] == 1]
sns.barplot(x='weathersit', y='cnt', data=df_2012, palette='viridis', ci=None)
plt.title('Total Penyewaan Sepeda Berdasarkan Kondisi Cuaca (Tahun 2012)')
plt.xlabel('Kondisi Cuaca')
plt.ylabel('Rata-rata Jumlah Penyewaan')
plt.show()
# Out:
# /tmp/ipykernel_78373/2327871649.py:3: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(x='weathersit', y='cnt', data=df_2012, palette='viridis', ci=None)
# /tmp/ipykernel_78373/2327871649.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='weathersit', y='cnt', data=df_2012, palette='viridis', ci=None)

# %% [markdown]
# ### Pertanyaan 2: Pada jam berapa penyewaan sepeda mencapai puncaknya pada hari kerja (workingday) dibandingkan hari libur (holiday)?

# %%
plt.figure(figsize=(12, 6))
sns.lineplot(x='hr', y='cnt', hue='workingday', data=hour_df, palette='Set1')
plt.title('Pola Penyewaan Sepeda Per Jam: Hari Kerja (1) vs Akhir Pekan/Libur (0)')
plt.xticks(range(0, 24))
plt.xlabel('Jam (0-23)')
plt.ylabel('Rata-rata Jumlah Penyewaan')
plt.legend(title='Hari Kerja', labels=['Libur/Weekend', 'Hari Kerja'])
plt.grid(True, linestyle='--', alpha=0.6)
plt.show()

# %% [markdown]
# **Insight:** (Opsional)
# - xxx
# - xxx

# %% [markdown]
# ## Analisis Lanjutan (Opsional)

# %% [markdown]
# # Mengelompokkan suhu (temp) menjadi kategori 'Cold', 'Moderate', 'Hot'
# # Sesuai data: temp asli dibagi 41 (max), jadi kita kembalikan ke skala derajat atau gunakan binning

# %%
def temp_category(temp):
    if temp < 0.3:
        return 'Cold'
    elif temp < 0.6:
        return 'Moderate'
    else:
        return 'Hot'

day_df['temp_cluster'] = day_df['temp'].apply(temp_category)

plt.figure(figsize=(8, 5))
sns.boxplot(x='temp_cluster', y='cnt', data=day_df, order=['Cold', 'Moderate', 'Hot'])
plt.title('Distribusi Penyewaan Sepeda Berdasarkan Klaster Suhu')
plt.show()

# %% [markdown]
# **Insight:** (Opsional)
# - xxx
# - xxx

# %%
main_data = hour_df.copy()
main_data.to_csv("main_data.csv", index=False)
print("Berhasil menyimpan data lengkap ke 'main_data.csv'!")
# Out:
# Berhasil menyimpan data lengkap ke 'main_data.csv'!

# %% [markdown]
# ## Conclusion & Recommendation

# %% [markdown]
# **Conclusion pertanyaan 1:** Conclusion Pertanyaan 1 (Pengaruh Cuaca):
#
# - Berdasarkan analisis, jumlah penyewaan sepeda mencapai titik tertinggi pada kondisi cuaca Clear/Partly Cloudy dengan total rata-rata penyewaan sebesar 4.876 unit per hari.
#
# - Sebaliknya, titik terendah terjadi pada kondisi Light Rain/Snow yang hanya mencatat rata-rata sebesar 1.803 unit per hari. Hal ini menunjukkan penurunan minat hingga 63% saat cuaca memburuk.
#
# **Conclusion pertanyaan 2:** Conclusion Pertanyaan 2 (Jam Puncak):
#
# - Pada hari kerja (workingday), beban puncak (peak load) tertinggi terjadi tepat pada pukul 17:00 dengan rata-rata 461 penyewaan, disusul pukul 08:00 dengan 414 penyewaan. Ini mengindikasikan penggunaan utama untuk komuter.
#
# - Pada hari libur (holiday), nilai tertinggi bergeser ke siang hari pada pukul 13:00 dengan rata-rata 385 penyewaan, menunjukkan pergeseran perilaku menjadi aktivitas rekreasi.

# %% [markdown]
# **Rekomendasi Action Item:**
# - 1. Maintenance Scheduling: Lakukan pemeliharaan unit pada jam operasional terendah (pukul 00:00 - 04:00) untuk meminimalkan gangguan layanan.
# - 2. Resource Allocation: Pastikan staf lapangan melakukan re-distribusi sepeda ke area perkantoran sebelum pukul 07:00 pagi di hari kerja untuk mengantisipasi lonjakan permintaan.
